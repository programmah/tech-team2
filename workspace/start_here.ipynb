# %% [markdown]
# # Add title here

# %% [markdown]
# ## Bootcamp Overview
#
# Add description here

# %% [markdown]
# ## Why the Bootcamp
#
# Add the justification for the Bootcamp here

# %% [markdown]
# ## Table of Contents
#
# - [List Bootcamp content here.](jupyter_notebook/)

# %% [markdown]
# ## Tutorial Duration
#
# Add tutorial duration here

# %% [markdown]
# ## Content level
#
# Add content level here: beginner, intermediate, or advanced

# %% [markdown]
# ## Target audience & prerequisites
#
# Add target audience and prerequisites here

# %% [markdown]
# ---

# %% [markdown]
# ## Licensing
#
# Copyright © 2026 OpenACC-Standard.org. This material is released by OpenACC-Standard.org, in collaboration with NVIDIA Corporation, under the Creative Commons Attribution 4.0 International (CC BY 4.0). These materials may include references to hardware and software developed by other entities; all applicable licensing and copyrights apply.
